# %%
import random

number = random.randint(1,100)
guess = 0

while guess != number:
    
    guess = int(input("Enter Guess: "))

    if (guess < number):
     print ("Guess higher!")
    elif (guess > number):
     print("Guess lower!")
    else:
     print("You won!")
# Out:
# Enter Guess:  1
# Guess higher!
# Enter Guess:  2
# Guess higher!
# Enter Guess:  5
# Guess higher!
# Enter Guess:  8
# Guess higher!
# Enter Guess:  10
# Guess higher!
# Enter Guess:  40
# Guess higher!
# Enter Guess:  70
# Guess higher!
# Enter Guess:  90
# Guess higher!
# Enter Guess:  99
# Guess lower!
# Enter Guess:  98
# Guess lower!
# Enter Guess:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 8
#       4 guess = 0
#       6 while guess != number:
# ----> 8     guess = int(input("Enter Guess: "))
#      10     if (guess < number):
#      11      print ("Guess higher!")
#
# ValueError: invalid literal for int() with base 10: ''
